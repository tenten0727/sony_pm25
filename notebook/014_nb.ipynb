# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import sys
import seaborn as sns
sys.path.append('../src/')
sys.path.append('../src/exp_013')
from preprocess import read_data, get_data

# %%
X_train, y, group, X_test, submit = get_data()
# Out:
# ==================== start run blocks ====================
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b16c8550> 0.589[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b10b1f10> 0.432[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b10b1b50> 0.395[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b10b1910> 0.397[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b1686a50> 0.395[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b16bee10> 0.436[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b16bea50> 0.406[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b16be890> 0.397[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b16bec10> 0.477[s]
# 	- <preprocess.YLagLeadBlock object at 0x7fb7b16bea90> 0.412[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7fb7b1660310> 2.243[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7fb7b1660110> 2.218[s]
# 	- <preprocess.CountEncodingBlock object at 0x7fb7a6de1e90> 0.472[s]
# run test = False 9.316[s]
# ...

# %%
X_train.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1 -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 2 -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 3 -34.42400  150.89345     179   4.554   7.159  15.819  30.752      39
# 4  51.22047    4.40026      93   4.011   4.555  12.859  18.655      78
#
#    o3_min  o3_mid  ...  TE_mean_is_holiday@TargetEncodingBlock  \
# 0   2.397   4.295  ...                               59.330321
# 1   0.736  12.527  ...                               59.480130
# 2   1.917  14.141  ...                               59.279363
# 3   0.514  11.869  ...                               59.279363
# 4   0.504   0.612  ...                               59.480130
#
#    TE_std_month@TargetEncodingBlock  TE_std_Country@TargetEncodingBlock  \
# 0                         51.959459                           27.064764
# ...

# %%
X_test.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -34.92866  138.59863     155   0.091   0.101   0.195   0.003     167
# 1 -33.86785  151.20732      23   1.037   2.272   3.391   1.347     142
# 2  50.85045    4.34878      28   0.096   0.101   0.104   0.000     114
# 3  43.84864   18.35644     122   0.479   4.589  16.560  60.820     118
# 4 -23.17944  -45.88694     158   6.198  13.478  20.327  36.498     129
#
#    o3_min  o3_mid  ...  TE_mean_is_holiday@TargetEncodingBlock  \
# 0   0.000   0.000  ...                               59.317855
# 1   7.797  34.414  ...                               59.317855
# 2   7.064  16.576  ...                               59.317855
# 3   0.513  22.445  ...                               59.317855
# 4   1.063   1.845  ...                               59.317855
#
#    TE_std_month@TargetEncodingBlock  TE_std_Country@TargetEncodingBlock  \
# 0                         51.047386                           26.154540
# ...

# %%
X_train['date'] = X_train['year'].astype(str) + '-' + X_train['month'].astype(str) + '-' + X_train['day'].astype(str)
X_train['date'] = pd.to_datetime(X_train['date'])

# %%
X_test['date'] = X_test['year'].astype(str) + '-' + X_test['month'].astype(str) + '-' + X_test['day'].astype(str)
X_test['date'] = pd.to_datetime(X_test['date'])

# %%
date = pd.Series(X_train['date'].unique())
{v: k for k, v in zip(date.index, date)}
# Out:
# {Timestamp('2019-01-01 00:00:00'): 0,
#  Timestamp('2019-01-02 00:00:00'): 1,
#  Timestamp('2019-01-03 00:00:00'): 2,
#  Timestamp('2019-01-04 00:00:00'): 3,
#  Timestamp('2019-01-05 00:00:00'): 4,
#  Timestamp('2019-01-06 00:00:00'): 5,
#  Timestamp('2019-01-07 00:00:00'): 6,
#  Timestamp('2019-01-08 00:00:00'): 7,
#  Timestamp('2019-01-09 00:00:00'): 8,
#  Timestamp('2019-01-10 00:00:00'): 9,
#  Timestamp('2019-01-11 00:00:00'): 10,
#  Timestamp('2019-01-12 00:00:00'): 11,
#  Timestamp('2019-01-13 00:00:00'): 12,
#  Timestamp('2019-01-14 00:00:00'): 13,
#  Timestamp('2019-01-15 00:00:00'): 14,
#  Timestamp('2019-01-16 00:00:00'): 15,
#  Timestamp('2019-01-17 00:00:00'): 16,
#  Timestamp('2019-01-18 00:00:00'): 17,
#  Timestamp('2019-01-19 00:00:00'): 18,
#  Timestamp('2019-01-20 00:00:00'): 19,
#  Timestamp('2019-01-21 00:00:00'): 20,
#  Timestamp('2019-01-22 00:00:00'): 21,
#  Timestamp('2019-01-23 00:00:00'): 22,
#  Timestamp('2019-01-24 00:00:00'): 23,
# ...
