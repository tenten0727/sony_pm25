# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import sys
import seaborn as sns
sys.path.append('../src/')
sys.path.append('../src/exp_008')
from preprocess import read_data, get_data

# %%
X_train, y, group, X_test, submit = get_data()
# Out:
# ../src/exp_008/preprocess.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = output_df['year'].astype(str) + '-' + output_df['month'].astype(str) + '-' + output_df['day'].astype(str)
# ../src/exp_008/preprocess.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = pd.to_datetime(output_df['date'])
# ../src/exp_008/preprocess.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['dayofweek'] = output_df['date'].dt.dayofweek.astype('category')
# ../src/exp_008/preprocess.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['is_holiday'] = 0
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# ../src/exp_008/preprocess.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_cluster'] = self.kmeans_model.predict(output_df)
# ../src/exp_008/preprocess.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_dist_'+str(i)] = dists.iloc[:, i]
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# ../src/exp_008/preprocess.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_cluster'] = self.kmeans_model.predict(output_df)
# ../src/exp_008/preprocess.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_dist_'+str(i)] = dists.iloc[:, i]
# ==================== start run blocks ====================
# ../src/exp_008/preprocess.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_lag_feature['y'] = y
# 	- <preprocess.LagLeadBlock object at 0x7f0b0766cb10> 0.575[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06df4f10> 0.420[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b09095750> 0.439[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06dcbc10> 0.469[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06dcbe90> 0.391[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b0928ff10> 0.532[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0af90d5090> 0.390[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0af90d50d0> 0.391[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0af90d5110> 0.459[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06dcbe50> 0.396[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f0b06786fd0> 1.926[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f0b0905d7d0> 1.931[s]
# 	- <preprocess.CountEncodingBlock object at 0x7f0b09299250> 1.285[s]
# run test = False 9.649[s]
# ==================== start run blocks ====================
# 	- <preprocess.LagLeadBlock object at 0x7f0b0766cb10> 0.024[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06df4f10> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b09095750> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06dcbc10> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06dcbe90> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b0928ff10> 0.010[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0af90d5090> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0af90d50d0> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0af90d5110> 0.009[s]
# 	- <preprocess.LagLeadBlock object at 0x7f0b06dcbe50> 0.009[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f0b06786fd0> 0.061[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f0b0905d7d0> 0.058[s]
# 	- <preprocess.CountEncodingBlock object at 0x7f0b09299250> 0.115[s]
# run test = True 0.358[s]

# %%
X_train.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1 -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2 -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3 -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4 -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
#
#    o3_min  o3_mid  ...  TE_meanis_holiday@TargetEncodingBlock  \
# 0   2.397   4.295  ...                              59.054433
# 1   3.092   7.572  ...                              58.551074
# 2   0.736  12.527  ...                              59.895027
# 3   1.917  14.141  ...                              59.895027
# 4   0.349   2.349  ...                              58.551074
#
#    TE_stdmonth@TargetEncodingBlock  TE_stdCountry@TargetEncodingBlock  \
# 0                        51.561721                          26.415061
# 1                        48.941711                          25.215408
# 2                        52.724575                          25.760983
# 3                        52.724575                          25.760983
# 4                        48.941711                          25.215408
#
#    TE_stddayofweek@TargetEncodingBlock  TE_stdis_holiday@TargetEncodingBlock  \
# 0                            38.644090                             38.606203
# 1                            37.351057                             37.287419
# 2                            39.243338                             39.201212
# 3                            39.243338                             39.201212
# 4                            37.351057                             37.287419
#
#    CE_year@CountEncodingBlock  CE_month@CountEncodingBlock  \
# 0                       69365                        14092
# 1                       69365                        14092
# 2                       69365                        14092
# 3                       69365                        14092
# 4                       69365                        14092
#
#    CE_day@CountEncodingBlock  CE_Country@CountEncodingBlock  \
# 0                       6590                           5656
# 1                       6590                           5656
# 2                       6590                           5656
# 3                       6590                           5656
# 4                       6590                           5656
#
#    CE_dayofweek@CountEncodingBlock
# 0                            28208
# 1                            28208
# 2                            28208
# 3                            28208
# 4                            28208
#
# [5 rows x 97 columns]

# %%
X_train.columns
# Out:
# Index(['lat', 'lon', 'co_cnt', 'co_min', 'co_mid', 'co_max', 'co_var',
#        'o3_cnt', 'o3_min', 'o3_mid', 'o3_max', 'o3_var', 'so2_cnt', 'so2_min',
#        'so2_mid', 'so2_max', 'so2_var', 'no2_cnt', 'no2_min', 'no2_mid',
#        'no2_max', 'no2_var', 'temperature_cnt', 'temperature_min',
#        'temperature_mid', 'temperature_max', 'temperature_var', 'humidity_cnt',
#        'humidity_min', 'humidity_mid', 'humidity_max', 'humidity_var',
#        'pressure_cnt', 'pressure_min', 'pressure_mid', 'pressure_max',
#        'pressure_var', 'ws_cnt', 'ws_min', 'ws_mid', 'ws_max', 'ws_var',
#        'dew_cnt', 'dew_min', 'dew_mid', 'dew_max', 'dew_var', 'fold', 'year',
#        'month', 'day', 'dayofweek', 'is_holiday', 'co_range', 'o3_range',
#        'so2_range', 'no2_range', 'temperature_range', 'humidity_range',
#        'pressure_range', 'ws_range', 'dew_range', 'Country', 'kmeans_cluster',
#        'kmeans_dist_0', 'kmeans_dist_1', 'kmeans_dist_2', 'kmeans_dist_3',
#        'kmeans_dist_4', 'kmeans_dist_5', 'kmeans_dist_6', 'kmeans_dist_7',
#        'kmeans_dist_8', 'kmeans_dist_9',
#        'lag-10Country_date_mean_pm25@LagLeadBlock',
#        'lag-7Country_date_mean_pm25@LagLeadBlock',
#        'lag-3Country_date_mean_pm25@LagLeadBlock',
#        'lag-2Country_date_mean_pm25@LagLeadBlock',
#        'lag-1Country_date_mean_pm25@LagLeadBlock',
#        'lag1Country_date_mean_pm25@LagLeadBlock',
#        'lag2Country_date_mean_pm25@LagLeadBlock',
#        'lag3Country_date_mean_pm25@LagLeadBlock',
#        'lag7Country_date_mean_pm25@LagLeadBlock',
#        'lag10Country_date_mean_pm25@LagLeadBlock',
#        'TE_meanmonth@TargetEncodingBlock',
#        'TE_meanCountry@TargetEncodingBlock',
#        'TE_meandayofweek@TargetEncodingBlock',
#        'TE_meanis_holiday@TargetEncodingBlock',
#        'TE_stdmonth@TargetEncodingBlock', 'TE_stdCountry@TargetEncodingBlock',
#        'TE_stddayofweek@TargetEncodingBlock',
#        'TE_stdis_holiday@TargetEncodingBlock', 'CE_year@CountEncodingBlock',
#        'CE_month@CountEncodingBlock', 'CE_day@CountEncodingBlock',
#        'CE_Country@CountEncodingBlock', 'CE_dayofweek@CountEncodingBlock'],
#       dtype='object')

# %%
X_train['date'] = X_train['year'].astype(str) + '-' + X_train['month'].astype(str) + '-' + X_train['day'].astype(str)
X_train['date'] = pd.to_datetime(X_train['date'])
X_train['y'] = y

# %%
import datetime
aaa = X_train.groupby(['Country', 'date'])['y'].agg('mean').reset_index()
aaa.head()
# Out:
#      Country       date          y
# 0  Australia 2019-01-01  85.202833
# 1  Australia 2019-01-02  46.119000
# 2  Australia 2019-01-03  44.508667
# 3  Australia 2019-01-04  31.402000
# 4  Australia 2019-01-05  32.119833
