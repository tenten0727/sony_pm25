# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import sys
import seaborn as sns
sys.path.append('../src/')
sys.path.append('../src/exp_007')
from preprocess import read_data, get_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_train, y, group, X_test, submit = get_data()
# Out:
# ../src/exp_007/preprocess.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = output_df['year'].astype(str) + '-' + output_df['month'].astype(str) + '-' + output_df['day'].astype(str)
# ../src/exp_007/preprocess.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = pd.to_datetime(output_df['date'])
# ../src/exp_007/preprocess.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
X_train.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1 -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2 -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3 -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4 -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
#
#    o3_min  o3_mid  ...  o3_mid_max_date@AggBlock  o3_mid_min_date@AggBlock  \
# 0   2.397   4.295  ...                    47.032                     0.307
# 1   3.092   7.572  ...                    47.032                     0.307
# 2   0.736  12.527  ...                    47.032                     0.307
# 3   1.917  14.141  ...                    47.032                     0.307
# 4   0.349   2.349  ...                    47.032                     0.307
#
#    so2_mid_mean_date@AggBlock  so2_mid_std_date@AggBlock  \
# ...

# %%
X_train.groupby('kmeans_cluster').count()
# Out:
#                   lat    lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# kmeans_cluster
# 0               53323  53323   53323   53323   53323   53323   53323   53323
# 1               18390  18390   18390   18390   18390   18390   18390   18390
# 2               15091  15091   15091   15091   15091   15091   15091   15091
# 3                1548   1548    1548    1548    1548    1548    1548    1548
# 4               69893  69893   69893   69893   69893   69893   69893   69893
# 5                  65     65      65      65      65      65      65      65
# 6                 800    800     800     800     800     800     800     800
# 7                5627   5627    5627    5627    5627    5627    5627    5627
# 8               30414  30414   30414   30414   30414   30414   30414   30414
# 9                 790    790     790     790     790     790     790     790
#
#                 o3_min  o3_mid  ...  o3_mid_max_date@AggBlock  \
# kmeans_cluster                  ...
# ...

# %%
X_train[['kmeans_dist_'+str(i) for i in range(4)]+['kmeans_cluster']]
# Out:
#         kmeans_dist_0  kmeans_dist_1  kmeans_dist_2  kmeans_dist_3  \
# 0            4.002289       8.196465       5.906641      21.653411
# 1            5.651273       8.339010       5.364150      21.876289
# 2            6.752867       8.989509       5.084029      21.357653
# 3            6.283763       8.246802       7.037652      21.245741
# 4            5.967874       8.338066       7.437897      21.212383
# ...               ...            ...            ...            ...
# 195936       5.268811       8.800740       6.358698      22.288925
# 195937       3.444905       7.930284       5.555520      21.616530
# 195938       3.116167       7.078505       6.516559      20.381658
# 195939       2.675870       6.869582       6.914374      20.103428
# 195940       4.394231       7.950067       5.915462      21.719474
#
#        kmeans_cluster
# 0                   0
# 1                   4
# 2                   2
# 3                   8
# 4                   8
# ...

# %%
X_train['date'] = X_train['year'].astype(str) + '-' + X_train['month'].astype(str) + '-' + X_train['day'].astype(str)
X_train['date'] = pd.to_datetime(X_train['date'])
