# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import sys
import seaborn as sns
sys.path.append('../src/')
sys.path.append('../src/exp_009')
from preprocess import read_data, get_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_train, y, group, X_test, submit = get_data()
# Out:
# ../src/exp_009/preprocess.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = output_df['year'].astype(str) + '-' + output_df['month'].astype(str) + '-' + output_df['day'].astype(str)
# ../src/exp_009/preprocess.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = pd.to_datetime(output_df['date'])
# ../src/exp_009/preprocess.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['dayofweek'] = output_df['date'].dt.dayofweek.astype('category')
# ../src/exp_009/preprocess.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['is_holiday'] = 0
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# ../src/exp_009/preprocess.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_cluster'] = self.kmeans_model.predict(output_df)
# ../src/exp_009/preprocess.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_dist_'+str(i)] = dists.iloc[:, i]
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)
# ../src/exp_009/preprocess.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_cluster'] = self.kmeans_model.predict(output_df)
# ../src/exp_009/preprocess.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['kmeans_dist_'+str(i)] = dists.iloc[:, i]
# ../src/exp_009/preprocess.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[f"{col1}x{col2}"] = output_df[col1] * output_df[col2]
# ../src/exp_009/preprocess.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[f"{col1}/{col2}"] = output_df[col1] / output_df[col2]
# ==================== start run blocks ====================
# ../src/exp_009/preprocess.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_lag_feature['y'] = y
# 	- <preprocess.YLagLeadBlock object at 0x7f067c365950> 0.525[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f067c4b9ed0> 0.403[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f06822fbed0> 0.399[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523a50> 0.406[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523b10> 0.397[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523ed0> 0.395[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523d50> 0.392[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f06795232d0> 0.395[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523d10> 0.392[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523f10> 0.394[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f06790f9090> 2.769[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f06790f9d90> 2.763[s]
# 	- <preprocess.CountEncodingBlock object at 0x7f067c3653d0> 1.288[s]
# run test = False 10.964[s]
# ==================== start run blocks ====================
# 	- <preprocess.YLagLeadBlock object at 0x7f067c365950> 0.038[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f067c4b9ed0> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f06822fbed0> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523a50> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523b10> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523ed0> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523d50> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f06795232d0> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523d10> 0.009[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f0679523f10> 0.009[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f06790f9090> 0.059[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f06790f9d90> 0.060[s]
# 	- <preprocess.CountEncodingBlock object at 0x7f067c3653d0> 0.115[s]
# run test = True 0.370[s]

# %%
X_train.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1 -12.46113  130.84185      47   2.594   3.181   4.828   1.208      49
# 2 -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 3 -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 4 -31.95224  115.86140      47   4.689   8.681  11.100  10.011      83
#
#    o3_min  o3_mid  ...  TE_meanis_holiday@TargetEncodingBlock  \
# 0   2.397   4.295  ...                              59.054433
# 1   3.092   7.572  ...                              58.551074
# 2   0.736  12.527  ...                              59.895027
# 3   1.917  14.141  ...                              59.895027
# 4   0.349   2.349  ...                              58.551074
#
#    TE_stdmonth@TargetEncodingBlock  TE_stdCountry@TargetEncodingBlock  \
# 0                        51.561721                          26.415061
# 1                        48.941711                          25.215408
# 2                        52.724575                          25.760983
# 3                        52.724575                          25.760983
# 4                        48.941711                          25.215408
#
#    TE_stddayofweek@TargetEncodingBlock  TE_stdis_holiday@TargetEncodingBlock  \
# 0                            38.644090                             38.606203
# 1                            37.351057                             37.287419
# 2                            39.243338                             39.201212
# 3                            39.243338                             39.201212
# 4                            37.351057                             37.287419
#
#    CE_year@CountEncodingBlock  CE_month@CountEncodingBlock  \
# 0                       69365                        14092
# 1                       69365                        14092
# 2                       69365                        14092
# 3                       69365                        14092
# 4                       69365                        14092
#
#    CE_day@CountEncodingBlock  CE_Country@CountEncodingBlock  \
# 0                       6590                           5656
# 1                       6590                           5656
# 2                       6590                           5656
# 3                       6590                           5656
# 4                       6590                           5656
#
#    CE_dayofweek@CountEncodingBlock
# 0                            28208
# 1                            28208
# 2                            28208
# 3                            28208
# 4                            28208
#
# [5 rows x 169 columns]

# %%
X_train['co_mid/o3_mid']
# Out:
# 0         0.603027
# 1         0.420100
# 2         0.095554
# 3         0.780991
# 4         3.695615
#             ...
# 195936    0.107047
# 195937    0.168591
# 195938    0.895904
# 195939    0.174745
# 195940    0.038217
# Name: co_mid/o3_mid, Length: 195941, dtype: float64
