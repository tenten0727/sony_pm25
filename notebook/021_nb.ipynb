# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter('ignore')

import pandas as pd
import numpy as np
import sys
import seaborn as sns
sys.path.append('../src/')
sys.path.append('../src/exp_021')
from preprocess import read_data, get_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
X_train, y, group, X_test, submit = get_data()
# Out:
# ==================== start run blocks ====================
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7361f84a90> 2.112[s]
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7332987cd0> 2.227[s]
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7328b2aa50> 2.058[s]
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7328b2ad50> 2.211[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332cda4d0> 0.289[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7361f84c50> 0.283[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332988090> 0.286[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f73329888d0> 0.286[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f73321301d0> 0.289[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130090> 0.292[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130f50> 0.290[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130ad0> 0.291[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332ce5850> 0.342[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130190> 0.301[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f7332ce5910> 1.507[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f7332ce5950> 1.527[s]
# 	- <preprocess.CountEncodingBlock object at 0x7f7332997c50> 0.295[s]
# run test = False 14.936[s]
# ==================== start run blocks ====================
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7361f84a90> 0.168[s]
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7332987cd0> 0.208[s]
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7328b2aa50> 0.155[s]
# 	- <preprocess.KnnLocationDateBlock object at 0x7f7328b2ad50> 0.204[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332cda4d0> 0.008[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7361f84c50> 0.007[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332988090> 0.007[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f73329888d0> 0.007[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f73321301d0> 0.007[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130090> 0.007[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130f50> 0.008[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130ad0> 0.008[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332ce5850> 0.007[s]
# 	- <preprocess.YLagLeadBlock object at 0x7f7332130190> 0.008[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f7332ce5910> 0.068[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f7332ce5950> 0.071[s]
# 	- <preprocess.CountEncodingBlock object at 0x7f7332997c50> 0.029[s]
# run test = True 0.999[s]
# ==================== start run blocks ====================
# 	- <preprocess.UmapFeatureBlock object at 0x7f7332994d10> 80.437[s]
# run test = False 80.437[s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_30601/3248335817.py in <module>
# ----> 1 X_train, y, group, X_test, submit = get_data()
#
# ~/work/signate/sony_pm25/src/exp_021/preprocess.py in get_data()
#     294     df_train = df_train[~df_train['City'].isin(['Ürümqi', 'Novosibirsk', 'Darwin', 'Perth'])].reset_index(drop=True)
#     295
# --> 296     df_train_feat, df_test_feat = create_feature(df_train, df_test)
#     297     y = df_train['pm25_mid']
#     298     group = df_train['City']
#
# ~/work/signate/sony_pm25/src/exp_021/preprocess.py in create_feature(df_train, df_test)
#     281         UmapFeatureBlock(55),
#     282     ]
# --> 283     df_train_feat = pd.concat([df_train_feat, run_blocks(df_train_feat, third_feature_blocks, y)], axis=1)
#     284     df_test_feat = pd.concat([df_test_feat, run_blocks(df_test_feat, third_feature_blocks, test=True)], axis=1)
#     285
#
# ~/work/signate/sony_pm25/src/utils.py in run_blocks(input_df, blocks, y, test)
#      26             with Timer(prefix='\t- {}'.format(str(block))):
#      27                 if not test:
# ---> 28                     out_i = block.fit(input_df, y=y)
#      29                 else:
#      30                     out_i = block.transform(input_df)
#
# ~/work/signate/sony_pm25/src/exp_021/preprocess.py in fit(self, input_df, y)
#     216         output_df = output_df.fillna(output_df.mean())
#     217
# --> 218         self.pipe.fit(output_df)
#     219         return self.transform(output_df)
#     220
#
# ~/.pyenv/versions/3.7.10/envs/kaggle/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~/.pyenv/versions/3.7.10/envs/kaggle/lib/python3.7/site-packages/umap/umap_.py in fit(self, X, y)
#    2686                 self.n_epochs,
#    2687                 init,
# -> 2688                 random_state,  # JH why raw data?
#    2689             )
#    2690             # Assign any points that are fully disconnected from our manifold(s) to have embedding
#
# ~/.pyenv/versions/3.7.10/envs/kaggle/lib/python3.7/site-packages/umap/umap_.py in _fit_embed_data(self, X, n_epochs, init, random_state)
#    2737             self.random_state is None,
#    2738             self.verbose,
# -> 2739             tqdm_kwds=self.tqdm_kwds,
#    2740         )
#    2741
#
# ~/.pyenv/versions/3.7.10/envs/kaggle/lib/python3.7/site-packages/umap/umap_.py in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1173             densmap_kwds=densmap_kwds,
#    1174             tqdm_kwds=tqdm_kwds,
# -> 1175             move_other=True,
#    1176         )
#    1177     else:
#
# ~/.pyenv/versions/3.7.10/envs/kaggle/lib/python3.7/site-packages/umap/layouts.py in optimize_layout_euclidean(head_embedding, tail_embedding, head, tail, n_epochs, n_vertices, epochs_per_sample, a, b, rng_state, gamma, initial_alpha, negative_sample_rate, parallel, verbose, densmap, densmap_kwds, tqdm_kwds, move_other)
#     394             dens_R,
#     395             dens_mu,
# --> 396             dens_mu_tot,
#     397         )
#     398
#
# KeyboardInterrupt:

# %%
X_train.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -27.46794  153.02809      38   0.749   2.590   2.633   0.850      29
# 1 -37.81400  144.96332      17   1.190   1.197   2.200   0.248     123
# 2 -32.92953  151.78010      63   4.586  11.044  14.802  24.186      90
# 3 -34.42400  150.89345     179   4.554   7.159  15.819  30.752      39
# 4  51.22047    4.40026      93   4.011   4.555  12.859  18.655      78
#
#    o3_min  o3_mid  ...  TE_mean_is_holiday@TargetEncodingBlock  \
# 0   2.397   4.295  ...                               59.330321
# 1   0.736  12.527  ...                               59.480130
# 2   1.917  14.141  ...                               59.279363
# 3   0.514  11.869  ...                               59.279363
# 4   0.504   0.612  ...                               59.480130
#
#    TE_std_month@TargetEncodingBlock  TE_std_Country@TargetEncodingBlock  \
# 0                         51.959459                           27.064764
# 1                         50.907354                           27.282343
# 2                         51.638930                           22.661095
# 3                         51.638930                           22.661095
# 4                         50.907354                           25.042350
#
#    TE_std_dayofweek@TargetEncodingBlock  \
# 0                             38.926034
# 1                             38.548017
# 2                             38.727758
# 3                             38.727758
# 4                             38.548017
#
#    TE_std_is_holiday@TargetEncodingBlock  CE_year@CountEncodingBlock  \
# 0                              38.848467                        2019
# 1                              38.547449                        2019
# 2                              38.696656                        2019
# 3                              38.696656                        2019
# 4                              38.547449                        2019
#
#    CE_month@CountEncodingBlock  CE_day@CountEncodingBlock  \
# 0                            1                          1
# 1                            1                          1
# 2                            1                          1
# 3                            1                          1
# 4                            1                          1
#
#    CE_Country@CountEncodingBlock  CE_dayofweek@CountEncodingBlock
# 0                           3635                            27700
# 1                           3635                            27700
# 2                           3635                            27700
# 3                           3635                            27700
# 4                           2773                            27700
#
# [5 rows x 102 columns]

# %%
X_test.head()
# Out:
#         lat        lon  co_cnt  co_min  co_mid  co_max  co_var  o3_cnt  \
# 0 -34.92866  138.59863     155   0.091   0.101   0.195   0.003     167
# 1 -33.86785  151.20732      23   1.037   2.272   3.391   1.347     142
# 2  50.85045    4.34878      28   0.096   0.101   0.104   0.000     114
# 3  43.84864   18.35644     122   0.479   4.589  16.560  60.820     118
# 4 -23.17944  -45.88694     158   6.198  13.478  20.327  36.498     129
#
#    o3_min  o3_mid  ...  TE_mean_is_holiday@TargetEncodingBlock  \
# 0   0.000   0.000  ...                               59.317855
# 1   7.797  34.414  ...                               59.317855
# 2   7.064  16.576  ...                               59.317855
# 3   0.513  22.445  ...                               59.317855
# 4   1.063   1.845  ...                               59.317855
#
#    TE_std_month@TargetEncodingBlock  TE_std_Country@TargetEncodingBlock  \
# 0                         51.047386                           26.154540
# 1                         51.047386                           26.154540
# 2                         51.047386                           28.259110
# 3                         51.047386                           42.442122
# 4                         51.047386                           28.792079
#
#    TE_std_dayofweek@TargetEncodingBlock  \
# 0                              38.43971
# 1                              38.43971
# 2                              38.43971
# 3                              38.43971
# 4                              38.43971
#
#    TE_std_is_holiday@TargetEncodingBlock  CE_year@CountEncodingBlock  \
# 0                              38.374781                        2019
# 1                              38.374781                        2019
# 2                              38.374781                        2019
# 3                              38.374781                        2019
# 4                              38.374781                        2019
#
#    CE_month@CountEncodingBlock  CE_day@CountEncodingBlock  \
# 0                            1                          1
# 1                            1                          1
# 2                            1                          1
# 3                            1                          1
# 4                            1                          1
#
#    CE_Country@CountEncodingBlock  CE_dayofweek@CountEncodingBlock
# 0                           3635                            27700
# 1                           3635                            27700
# 2                           2773                            27700
# 3                            921                            27700
# 4                           2013                            27700
#
# [5 rows x 101 columns]
