# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import sys
import seaborn as sns
sys.path.append('../src/')
sys.path.append('../src/exp_004')
from preprocess import read_data, get_data

# %%
X_train, y, group, X_test, submit = get_data()
# Out:
# ==================== start run blocks ====================
# 	- <preprocess.NumericBlock object at 0x7f6ec34abe90> 0.167[s]
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ../src/exp_004/preprocess.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[col] = output_df[col].astype(float)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ../src/exp_004/preprocess.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[col] = output_df[col].astype(float)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ../src/exp_004/preprocess.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[col] = output_df[col].astype(float)
# /home/yoshikawa/.pyenv/versions/3.7.10/envs/sony_pm25/lib/python3.7/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# ../src/exp_004/preprocess.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[col] = output_df[col].astype(float)
# 	- <preprocess.TargetEncodingBlock object at 0x7f6ec342bc10> 1.496[s]
# 	- <preprocess.RangeMaxMinBlock object at 0x7f6ec3524990> 0.030[s]
# ../src/exp_004/preprocess.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = input_df['year'].astype(str) + '-' + input_df['month'].astype(str) + '-' + input_df['day'].astype(str)
# ../src/exp_004/preprocess.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['date'] = pd.to_datetime(output_df['date'])
# ../src/exp_004/preprocess.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['dayofweek'] = output_df['date'].dt.dayofweek.astype('category')
# ../src/exp_004/preprocess.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df[col] = output_df[col].map(self.test_TE[col])
# 	- <preprocess.DatetimeBlock object at 0x7f6ec3446d90> 0.922[s]
# run test = False 2.745[s]
# ==================== start run blocks ====================
# 	- <preprocess.NumericBlock object at 0x7f6ec34abe90> 0.016[s]
# 	- <preprocess.TargetEncodingBlock object at 0x7f6ec342bc10> 0.011[s]
# 	- <preprocess.RangeMaxMinBlock object at 0x7f6ec3524990> 0.013[s]
# 	- <preprocess.DatetimeBlock object at 0x7f6ec3446d90> 0.255[s]
# run test = True 0.320[s]

# %%
X_train['y'] = y
corr = X_train.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr['y'].sort_values()
# Out:
# ws_mid@NumericBlock           -0.282529
# pressure_min@NumericBlock     -0.197878
# pressure_mid@NumericBlock     -0.175993
# ws_max@NumericBlock           -0.147863
# wsrange@RangeMaxMinBlock      -0.133504
#                                  ...
# Country@TargetEncodingBlock    0.391048
# no2_max@NumericBlock           0.391576
# co_mid@NumericBlock            0.397640
# no2_mid@NumericBlock           0.524316
# y                              1.000000
# Name: y, Length: 61, dtype: float64
